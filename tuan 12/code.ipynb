# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.array([2.352, 3.804, 3.804, 2.352, 0, -2.352, -3.804, -3.804, -2.352, 0, 2.352, 3.804])
y = np.array([3.470, 3.804, 3.804, 3.470, 0, -3.470, -3.804, -3.804, -3.470, 0, 3.470, 3.804])
xd = np.array([2.352, 3.804, 3.804, 2.352, 0, -2.352, -3.804, -3.804, -2.352, 0, 2.352, 3.804])

# %%
fig, axes = plt.subplots(3, 1, figsize=(8, 5))
fig = plt.subplot(311)
plt.setp(axes, xticks=[], yticks=[-4, -2, 0, 2, 4])
plt.stem(x)
# plt.grid()
# plt.axis('off')
plt.xticks([])
fig = plt.subplot(312)
plt.stem(y)
# plt.grid()
# plt.axis('off')
fig = plt.subplot(313)
plt.stem(xd)
# plt.grid()
# plt.axis('off')
plt.savefig('image.png', dpi=400)
plt.show()
