# %%
import numpy as np
from scipy.io import wavfile
from scipy.signal import correlate, fftconvolve
from scipy.interpolate import interp1d
import librosa
import matplotlib.pyplot as plt

data, sample_rate = librosa.load("A96.wav")
fig, ax = plt.subplots(2, 1, sharex=False, figsize=(16, 8))
ax[0].plot(data)
autoCorrelated = librosa.autocorrelate(data, max_size=500)
ax[1].plot(autoCorrelated)
plt.savefig("A_image.png", dpi=400)
plt.show()

# %%
ai = librosa.lpc(data, 14)
ai = ai + [0]*(256-len(ai))
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_17712\3796229927.py:1: FutureWarning: Pass order=14 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   ai = librosa.lpc(data, 14)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# e:\AIWorkplace\Speech\tuan 10\code.ipynb Cell 2 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/e%3A/AIWorkplace/Speech/tuan%2010/code.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> ai = librosa.lpc(data, 14)
# ----> <a href='vscode-notebook-cell:/e%3A/AIWorkplace/Speech/tuan%2010/code.ipynb#W1sZmlsZQ%3D%3D?line=1'>2</a> ai = ai + [0]*(256-len(ai))
#
# ValueError: operands could not be broadcast together with shapes (15,) (241,)

# %%
ai.shape
# Out:
# (15,)

# %%
ai
# Out:
# array([  1.        ,  -4.464366  ,   9.326514  , -11.967109  ,
#         10.22888   ,  -5.8731093 ,   2.1542203 ,  -0.44012856,
#          0.05838192,  -0.03202724,   0.10817181,  -0.2354679 ,
#          0.22526819,  -0.10288147,   0.01938824], dtype=float32)
